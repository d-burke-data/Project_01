# %%
from fredapi import Fred
import pandas as pd
from config1 import api_key
from pprint import pprint

# Initialize the Fred client
fred = Fred(api_key=api_key)

# %%
states = {
        #  "United States": "US",
         "Alabama": "AL",
         "Alaska": "AK",
         "Arizona": "AZ",
         "Arkansas": "AR",
         "California": "CA",
         "Colorado":"CO",
         "Connecticut": "CT",
         "Delaware": "DE",
         "District of Columbia": "DC",
         "Florida": "FL",
         "Georgia": "GA",
         "Hawaii": "HI",
         "Idaho": "ID",
         "Illinois": "IL", 
         "Indiana": "IN",
         "Iowa": "IA",
         "Kansas": "KS",
         "Kentucky": "KY",
         "Louisana": "LA",
         "Maine": "ME",
         "Maryland": "MD",
         "Massachusetts":"MA",
         "Michigan": "MI",
         "Minnesota": "MN",
         "Mississippi": "MS",
         "Missour": "MO",
         "Montana": "MT",
         "Nebraska": "NE",
         "Nevada": "NV",
         "New Hampshire": "NH",
         "New Jersey": "NJ",
         "New Mexico": "NM", 
         "New York": "NY",
         "North Carolina": "NC",
         "North Dakota": "ND",
         "Ohio": "OH",
         "Oklahoma": "OK",
         "Oregon": "OR",
         "Pennsylvania": "PA",
         "Rhode Island": "RI",
         "South Carolina": "SC",
         "South Dakota": "SD",
         "Tennessee": "TN",
         "Texas": "TX",
         "Utah": "UT",
         "Vermont": "VT",
         "Virginia": "VA",
         "Washington": "WA",
         "West Virginia": "WV",
         "Wisconsin": "WI",
         "Wyoming": "WY",
         }

# %%
# Dictionary to hold data for all states
ownership_rate_data = {}

# Fetch data for each state
for state, abbreviation in states.items():
    # Construct the series ID for each state
    series_id = f"{abbreviation}HOWN"

    # Fetch the series data from FRED
    ownership_data = fred.get_series(series_id, observation_start="2000-01-31")
    ownership_rate_data[state] = ownership_data

# Convert the data to a DataFrame
ownership_rate_df = pd.DataFrame(ownership_rate_data)
ownership_rate_df.index.name = "Date"
pprint(ownership_rate_df)
# Out:
#             Alabama  Alaska  Arizona  Arkansas  California  Colorado  \
# Date
# 2000-01-01     73.2    66.4     68.0      68.9        57.1      68.3
# 2001-01-01     73.2    65.3     68.1      71.2        58.2      68.5
# 2002-01-01     73.7    67.1     65.6      70.3        57.7      68.9
# 2003-01-01     76.2    70.0     67.0      69.6        58.9      71.3
# 2004-01-01     78.0    67.2     68.7      69.1        59.7      71.1
# 2005-01-01     76.6    66.0     71.1      69.2        59.7      71.0
# 2006-01-01     74.2    67.2     71.6      70.8        60.2      70.1
# 2007-01-01     73.3    66.6     70.4      69.5        58.3      70.2
# 2008-01-01     73.0    66.4     69.1      68.9        57.5      69.0
# 2009-01-01     74.1    66.8     68.9      68.5        57.0      68.4
# 2010-01-01     73.2    65.7     66.6      67.9        56.1      68.5
# 2011-01-01     72.9    64.4     66.0      67.6        55.3      65.9
# 2012-01-01     71.9    63.7     65.3      66.0        54.5      65.3
# 2013-01-01     72.7    64.6     65.1      65.4        54.3      64.4
# 2014-01-01     72.1    64.9     63.5      65.4        54.2      65.0
# 2015-01-01     70.0    62.3     61.7      67.1        54.3      63.6
# 2016-01-01     69.7    65.2     61.9      67.6        53.8      62.4
# 2017-01-01     70.0    65.5     64.4      65.0        54.4      63.7
# 2018-01-01     70.3    63.7     65.7      64.7        55.1      64.4
# 2019-01-01     70.7    62.6     65.8      65.3        54.8      64.7
# 2020-01-01     74.8    64.1     68.7      68.8        55.9      64.9
# 2021-01-01     73.4    64.0     65.2      66.1        54.2      65.9
# 2022-01-01     72.1    65.1     68.1      66.8        55.3      67.4
# 2023-01-01     73.8    64.3     69.7      65.9        55.8      67.2
#
#             Connecticut  Delaware  District of Columbia  Florida  ...  \
# Date                                                              ...
# 2000-01-01         70.0      72.0                  41.9     68.4  ...
# 2001-01-01         71.8      75.4                  42.7     69.2  ...
# 2002-01-01         71.5      75.6                  44.1     68.7  ...
# 2003-01-01         73.0      77.2                  43.0     69.5  ...
# 2004-01-01         71.7      77.3                  45.6     72.2  ...
# 2005-01-01         70.5      75.8                  45.8     72.4  ...
# 2006-01-01         71.1      76.8                  45.9     72.4  ...
# 2007-01-01         70.3      76.8                  47.2     71.8  ...
# 2008-01-01         70.7      76.2                  44.1     71.1  ...
# 2009-01-01         70.5      76.5                  44.9     70.9  ...
# 2010-01-01         70.8      74.7                  45.6     69.3  ...
# 2011-01-01         70.6      74.2                  44.8     69.0  ...
# 2012-01-01         68.8      73.4                  45.0     67.0  ...
# 2013-01-01         68.5      74.1                  44.6     66.1  ...
# 2014-01-01         67.4      74.3                  41.5     64.9  ...
# 2015-01-01         66.5      73.3                  40.4     64.8  ...
# 2016-01-01         64.2      73.0                  40.8     64.3  ...
# 2017-01-01         66.1      70.0                  40.3     64.1  ...
# 2018-01-01         65.3      70.8                  39.9     65.5  ...
# 2019-01-01         64.3      73.1                  40.2     66.0  ...
# 2020-01-01         66.9      77.9                  42.5     68.7  ...
# 2021-01-01         66.1      73.5                  42.3     67.2  ...
# 2022-01-01         64.8      74.9                  42.3     67.3  ...
# 2023-01-01         68.2      75.7                  40.2     67.3  ...
#
#             South Dakota  Tennessee  Texas  Utah  Vermont  Virginia  \
# Date
# 2000-01-01          71.2       70.9   63.8  72.7     68.7      73.9
# 2001-01-01          71.5       69.7   63.9  72.4     69.8      75.1
# 2002-01-01          71.5       70.3   63.4  72.8     70.3      74.4
# 2003-01-01          70.9       70.8   64.5  73.4     71.4      75.0
# 2004-01-01          68.5       71.6   65.5  74.9     72.0      73.4
# 2005-01-01          68.4       72.4   65.9  73.9     74.2      71.2
# 2006-01-01          70.6       71.3   66.0  73.5     74.0      71.1
# 2007-01-01          70.4       70.2   66.0  74.9     73.7      71.5
# 2008-01-01          70.4       71.7   65.5  76.2     72.8      70.6
# 2009-01-01          69.6       71.1   65.4  74.1     74.3      69.7
# 2010-01-01          70.6       71.0   65.3  72.5     73.6      68.7
# 2011-01-01          69.3       69.3   64.3  71.4     74.6      67.9
# 2012-01-01          69.2       67.9   64.3  71.1     73.4      67.8
# 2013-01-01          67.8       66.8   63.3  70.9     73.0      68.1
# 2014-01-01          69.2       66.7   62.2  70.9     73.5      68.7
# 2015-01-01          70.1       66.5   61.9  69.9     71.8      67.1
# 2016-01-01          69.4       66.4   61.5  71.3     71.3      66.3
# 2017-01-01          67.8       67.2   61.7  71.0     71.1      67.5
# 2018-01-01          69.1       68.0   62.7  72.2     71.4      66.0
# 2019-01-01          69.5       68.8   62.4  71.9     70.9      67.6
# 2020-01-01          71.4       70.0   66.5  71.7     73.1      70.4
# 2021-01-01          71.1       67.7   64.1  68.8     73.9      68.0
# 2022-01-01          70.8       67.3   63.6  71.2     72.7      67.4
# 2023-01-01          69.3       68.9   63.6  70.3     73.7      69.1
#
#             Washington  West Virginia  Wisconsin  Wyoming
# Date
# 2000-01-01        63.6           75.9       71.8     71.0
# 2001-01-01        66.4           76.4       72.3     73.5
# 2002-01-01        66.9           77.2       72.2     73.0
# 2003-01-01        65.9           78.1       72.8     72.9
# 2004-01-01        66.0           80.3       73.3     72.8
# 2005-01-01        67.6           81.3       71.1     72.8
# 2006-01-01        66.7           78.4       70.2     73.7
# 2007-01-01        66.8           77.6       70.5     73.2
# 2008-01-01        66.2           77.8       70.4     73.3
# 2009-01-01        65.5           78.7       70.4     73.8
# 2010-01-01        64.4           79.0       71.0     73.4
# 2011-01-01        64.2           78.7       68.5     71.1
# 2012-01-01        63.5           75.8       67.5     70.3
# 2013-01-01        62.7           76.8       68.5     70.5
# 2014-01-01        63.6           75.6       67.8     70.8
# 2015-01-01        62.6           74.9       66.6     69.9
# 2016-01-01        61.6           74.8       67.7     70.2
# 2017-01-01        63.6           75.1       68.0     70.4
# 2018-01-01        64.9           74.7       67.9     71.1
# 2019-01-01        63.8           75.6       66.1     71.3
# 2020-01-01        64.1           78.2       67.9     73.9
# 2021-01-01        63.4           79.0       68.3     72.1
# 2022-01-01        66.6           78.6       70.0     75.3
# 2023-01-01        66.3           77.0       69.2     74.5
#
# [24 rows x 51 columns]
